# %% [markdown]
# Paquetes almacenados en requeriments.txt con pip freeze para instalar facilmente en entorno
# Nota: Recomendación usar poetry o similar para ges
# tionar facilmente los entornos

# %% [markdown]
# # Ejemplo

# %%
from datetime import *
from dateutil.relativedelta import *
now = datetime.now()
print(now)

now = now + relativedelta(months=1, weeks=1, hour=10)

print(now)
# Out:
# 2022-02-14 18:41:03.163079
# 2022-03-21 10:41:03.163079
