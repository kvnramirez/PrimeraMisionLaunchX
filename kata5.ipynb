# %% [markdown]
# # Ejercicio 1: Utilizar operadores aritmeticos

# %%
first_planet = 149597870
second_planet = 778547200
distance_km = second_planet - first_planet
print('Distancia km: ', distance_km)

distance_mi = distance_km * 0.621
print('Distancia millas: ', distance_mi)
# Out:
# Distancia km:  628949330
# Distancia millas:  390577533.93

# %% [markdown]
# # Ejercicio 2: Convertir cadenas en numeros y usar valores absolutos

# %%
first_planet = input('Introduzca la distancia del sol para el primer planeta en KM')
second_planet = input('Introduzca la distancia desde el sol para el segundo planeta en KM')
# Hacer cast
first_planet = int(first_planet)
second_planet = int(second_planet)
# Calculos
distance_km = second_planet - first_planet
print('Distancia en km:', distance_km)

# Convertir a millas
distance_mi = distance_km * 0.621
print('Distancia en millas:', abs(distance_mi))
# Out:
# Distancia en km: 1
# Distancia en millas: 0.621
