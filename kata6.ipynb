# %% [markdown]
# # ejercicio 1: crear y usar listas de python

# %%
planetas = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

print('There are', len(planetas), 'planets')
# Out:
# There are 8 planets

# %%
planetas.append('Pluto')

print(planetas[-1], 'is the last planet')
# Out:
# Pluto is the last planet

# %% [markdown]
# # Ejercicio 2

# %%
planetas = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']
user_planet = input('Please enter the name of the planet (with a capital letter to start)')
try:
    planet_index = planetas.index(user_planet)
except ValueError:
    print('No existe el planeta: ', user_planet)
else:
    print('Here are the planets closer than ' + user_planet)
    print(planetas[0:planet_index])
    print('Here are the planets further than ' + user_planet)
    print(planetas[planet_index + 1:])
# Out:
# No existe el planeta:  earth
