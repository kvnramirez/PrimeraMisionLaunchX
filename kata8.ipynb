# %% [markdown]
# # Ejercicio 1: crear diccionario en python

# %%
planet = {
    'name': 'Mars',
    'moons': 2
}

planet_v2 = dict()
planet_v2['name'] = 'Mars'
planet_v2['moons'] = 2

print(f'{planet["name"]} has {planet["moons"]} moons')
print(f'{planet_v2["name"]} has {planet_v2["moons"]} moons')

planet['circumference (km)'] = planet_v2['circumference (km)'] = {
    'polar': 6752,
    'equatorial': 6792
}

print(f'{planet["name"]} has a polar circumference of {planet["circumference (km)"]["polar"]}')
print(f'{planet_v2["name"]} has a polar circumference of {planet_v2["circumference (km)"]["polar"]}')
# Out:
# Mars has 2 moons
# Mars has 2 moons
# Mars has a polar circumference of 6752
# Mars has a polar circumference of 6752

# %% [markdown]
# # Ejercicio 2: programacion dinamica con diccionarios

# %%
planet_moons = {
    'mercury': 0,
    'venus': 0,
    'earth': 1,
    'mars': 2,
    'jupiter': 79,
    'saturn': 82,
    'uranus': 27,
    'neptune': 14,
    'pluto': 5,
    'haumea': 2,
    'makemake': 1,
    'eris': 1
}

moons = planet_moons.values()
planets = len(planet_moons.keys())

total_moons = 0
for moon in moons:
    total_moons = total_moons + moon

average = total_moons / planets

print(average)
# Out:
# 17.833333333333332
